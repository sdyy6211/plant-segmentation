# %%
import pandas as pd
from io import BytesIO
from PIL import Image
import requests
import os
import numpy as np
import torch
import time
from utils_d import *

# %%
exp = pd.read_csv(r'E:\sp\export-2020-05-19T07_34_34.053Z.csv')

# %%
exp_test = pd.read_csv(r'E:\sp\export-2020-03-12T20_58_33.907Z.csv')

# %%
train_list = pd.read_excel(r'E:\UCL\Dissertation\label\train_list.xlsx',header=None)[0]
test_list = pd.read_excel(r'E:\UCL\Dissertation\label\test_list.xlsx',header=None)[0]

exp_train = exp[exp['External ID'].apply(lambda x: x in train_list.values)].reset_index(drop = True)
exp_test = exp_test[exp_test['External ID'].apply(lambda x: x in test_list.values)].reset_index(drop = True)

# %%
save_image(exp_train,r'E:\UCL\Dissertation\label\download')
# Out:
# https://api.labelbox.com/masks/feature/ck60ytqpr226o0yb1v8ak3kud?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjazVnemFoZHRtY2RzMDc3MGRycGlyb3RmIiwib3JnYW5pemF0aW9uSWQiOiJjazVnemFoZDVoeW8zMDg5OWVlbDlpbnNzIiwiaWF0IjoxNTg5ODczNjc0LCJleHAiOjE1OTI0NjU2NzR9.p-yeYXH9021M4BGsGewaHaL364_KfoNS40jXMGfNr1w
# animage (9) window saved successfully
# https://api.labelbox.com/masks/feature/ck60yufvf1nmv0xb1003sxg9e?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjazVnemFoZHRtY2RzMDc3MGRycGlyb3RmIiwib3JnYW5pemF0aW9uSWQiOiJjazVnemFoZDVoeW8zMDg5OWVlbDlpbnNzIiwiaWF0IjoxNTg5ODczNjc0LCJleHAiOjE1OTI0NjU2NzR9.p-yeYXH9021M4BGsGewaHaL364_KfoNS40jXMGfNr1w
# animage (9) sky saved successfully
# ...

# %%
save_image(exp_test,r'E:\UCL\Dissertation\label\download_test')
# Out:
# WhatsApp Image 2019-08-28 at 15 sky saved successfully
# WhatsApp Image 2019-08-28 at 15 window saved successfully
# WhatsApp Image 2019-08-28 at 15 plants saved successfully
# WhatsApp Image 2019-08-28 at 15 holes saved successfully
# WhatsApp Image 2019-08-28 at 15 sign saved successfully
# WhatsApp Image 2019-08-28 at 15 gate saved successfully
# WhatsApp Image 2019-08-28 at 15 brick saved successfully
# 6 sky saved successfully
# 6 plants saved successfully
# 6 sign saved successfully
# 6 window saved successfully
# 6 holes saved successfully
# 6 gate saved successfully
# 6 brick saved successfully
# animage (26) plants saved successfully
# animage (26) sky saved successfully
# animage (26) window saved successfully
# animage (26) holes saved successfully
# animage (26) gate saved successfully
# animage (26) brick saved successfully
# bothwell1-14-8-2019 plants saved successfully
# bothwell1-14-8-2019 sign saved successfully
# bothwell1-14-8-2019 gate saved successfully
# ...

# %%
csv_ = create_csv(exp_train,r'E:\UCL\Dissertation\label\input')
csv_.to_csv(r'E:\UCL\Dissertation\label\lb_2.csv',index=False)

# %%
csv_test = create_csv(exp_test,r'E:\UCL\Dissertation\label\input_test')
csv_test[['x_name','window','sky','plants','brick','holes','gate','sign']].to_csv(r'E:\UCL\Dissertation\label\lb_test_2.csv',index=False)

# %%
bbox = save_bbox(exp_test)
bbox.to_csv(r'E:\UCL\Dissertation\label\bbox_test.csv',index=False)
# Out:
# WhatsApp Image 2019-08-28 at 15 plant bbox saved successfully
# 6 plant bbox saved successfully
# animage (26) plant bbox saved successfully
# bothwell1-14-8-2019 plant bbox saved successfully
# WhatsApp Image 2019-09-08 at 14 plant bbox saved successfully
# 1130_2 plant bbox saved successfully
# 1130_2 plant bbox saved successfully
# animage (29) plant bbox saved successfully
# bothwell2-18-07-2019 plant bbox saved successfully
# 20200104_130511 plant bbox saved successfully
# 20200104_130511 plant bbox saved successfully
# bothwell4-14-8-2019 plant bbox saved successfully
# WhatsApp Image 2019-10-05 at 15 plant bbox saved successfully
# WhatsApp Image 2019-10-05 at 15 plant bbox saved successfully
# animage (3) plant bbox saved successfully
# animage (3) plant bbox saved successfully
# animage (3) plant bbox saved successfully
# animage (3) plant bbox saved successfully
# animage (35) plant bbox saved successfully
# animage (35) plant bbox saved successfully
# ...

# %%
bbox = pd.read_csv(r'E:\UCL\Dissertation\label\bbox_test.csv')

# %%
cropped_lb = seperate_labels(bbox,
                r'E:\UCL\Dissertation\label\input_test',
                r'E:\UCL\Dissertation\label\download_test',
                r'D:\codes\python\area51m\seg\ttt',
                r'D:\codes\python\area51m\seg\tt')

cropped_lb.to_csv(r'D:\codes\python\area51m\seg\cropped_lb_test.csv',index = False)
