# %%
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import requests
import os
import numpy as np

import torch
from torchvision import models
from torch.nn import CrossEntropyLoss
from torch.nn.functional import softmax
from torch.optim import Adam,lr_scheduler
from torch.nn import functional as F
from torchvision import transforms
from torch.utils.data import Dataset

# %%
Deeplabv3plus_path = r'E:\codes\python\area51m\pytorch_deeplab_xception'
Data_path = r'E:\UCL\Dissertation\label'
CroppedTrainingLabelNames = 'CroppedTrainingLabelNames.csv'
CroppedTestLabelNames = 'CroppedTestLabelNames.csv'
CroppedTraining_input_folder = 'cropped_input'
CroppedTraining_label_folder = 'cropped_label'
CroppedTest_input_folder = 'cropped_input_test'
CroppedTest_label_folder = 'cropped_label_test'
ModelPath = r'E:\data\MODELS' 
TwoStageModelName = 'model_deeplabv3+_resnet'

# %%
from utils import *
import sys
import os

device = torch.device("cuda:0")

sys.path.append(Deeplabv3plus_path)
from pytorch_deeplab_xception.modeling import deeplab

os.environ['TORCH_HOME'] = ModelPath

# %%
num_c = 2

dl = deeplab.DeepLab(num_classes=num_c,backbone = 'resnet').to(device)

for name, param in dl.named_parameters():                
    if name.startswith('backbone'):
        param.requires_grad = False

# %%
image_size = (200,200)

transform = transforms.Compose([transforms.Resize(image_size),
                                transforms.ColorJitter(brightness = 0.15,
                                                       saturation = 0.1,
                                                       hue = 0.01,
                                                       contrast = 0.15),
                                transforms.ToTensor(),
                                transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# %%
data = pd.read_csv(r'{0}\{1}'.format(Data_path,TrainingLabelNames))

dataset_train = Segdata(transform,image_size,
                        TrainingLabelNames,Data_path,[Training_input_folder,Training_label_folder])

dataset_test = Segdata(transform,image_size,
                       TestLabelNames,Data_path,[Test_input_folder,Test_label_folder])

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=6, 
                                         shuffle=True, num_workers=0,drop_last  = True)

dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=1, num_workers=0,drop_last  = False)

# %%
plist = [
         {'params': dl.decoder.parameters(),'lr':1e-2}
         ]

freq = 1/get_frequency(data,image_size,num_c,Data_path,Training_label_folder)

criterion = CrossEntropyLoss(weight=freq)

optimizer = Adam(params=plist)

scheduler = lr_scheduler.StepLR(optimizer, step_size=33,gamma=0.1)

loss_list = []

best_val_loss = float('inf')

n_epoch = 50

# %%
for epoch in range(n_epoch):
    training_loss,training_iou = train(dl,dataloader_train,optimizer,criterion,loss_list,num_c)
    val_loss,val_iou = evaluate(dl,dataloader_test,criterion,num_c)
    scheduler.step()
    print('finished {0}th training'.format(epoch+1))
    print('training loss: {0}, training iou: {1}'.format(training_loss.item(),training_iou))
    print('validation loss: {0}, validation iou: {1}'.format(val_loss.item(),val_iou))
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(dl.state_dict(), r'{0}\{1}_best_twostage.pt'.format(ModelPath,TwoStageModelName))
torch.save(dl.state_dict(), r'{0}\{1}_last_twostage.pt'.format(ModelPath,TwoStageModelName))
# Out:
# finished 1th training
# training loss: 1.7526046872138976, training iou: 0.24796374355500883
# validation loss: 2.2254591514666875, validation iou: 0.2867390079152933
# finished 2th training
# training loss: 0.5730765402317047, training iou: 0.26883554580616364
# validation loss: 0.5446149570246538, validation iou: 0.34306694867276655
# finished 3th training
# training loss: 0.36670774817466734, training iou: 0.5010587407674044
# validation loss: 0.8193626450995605, validation iou: 0.4239502843316045
# finished 4th training
# training loss: 0.3954370319843292, training iou: 0.5116235148559952
# validation loss: 0.984543198098739, validation iou: 0.3983672316118261
# finished 5th training
# training loss: 0.3427548885345459, training iou: 0.5567730400983748
# validation loss: 0.8770303200930357, validation iou: 0.397185985041285
# finished 6th training
# training loss: 0.3148632347583771, training iou: 0.5741098115149523
# validation loss: 0.5858125652497014, validation iou: 0.43558058826362556
# finished 7th training
# training loss: 0.31183300614356996, training iou: 0.5738543443053812
# validation loss: 0.40938753026227154, validation iou: 0.4931830375505985
# finished 8th training
# training loss: 0.2833855986595154, training iou: 0.5904191154448355
# validation loss: 0.3481874231869976, validation iou: 0.5235783035020017
# finished 9th training
# training loss: 0.2781726658344269, training iou: 0.5762165022681346
# validation loss: 0.39330098597953717, validation iou: 0.4995774277354131
# finished 10th training
# training loss: 0.27814646661281583, training iou: 0.5679500013095857
# validation loss: 0.3756616646734377, validation iou: 0.4848590716287887
# finished 11th training
# training loss: 0.2663609266281128, training iou: 0.574797349729296
# validation loss: 0.3906668350100517, validation iou: 0.4882122897562667
# finished 12th training
# training loss: 0.26102755069732664, training iou: 0.5780631962110838
# validation loss: 0.3414633771404624, validation iou: 0.5078506319060964
# finished 13th training
# training loss: 0.2681668668985367, training iou: 0.5687118535267095
# validation loss: 0.34815322092423834, validation iou: 0.5256484081668623
# finished 14th training
# training loss: 0.26078100502491, training iou: 0.5715298921755438
# validation loss: 0.32426162948831916, validation iou: 0.5333535414672509
# finished 15th training
# training loss: 0.2538614243268967, training iou: 0.5774196350515294
# validation loss: 0.3274106776341796, validation iou: 0.5180259576336207
# finished 16th training
# training loss: 0.2568787693977356, training iou: 0.5733469891251118
# validation loss: 0.33415528408562145, validation iou: 0.5162445388470159
# finished 17th training
# training loss: 0.2530372470617294, training iou: 0.573421097259206
# validation loss: 0.3145941738039255, validation iou: 0.5234447238143837
# finished 18th training
# training loss: 0.2465975284576416, training iou: 0.5703086859477307
# validation loss: 0.3262867955490947, validation iou: 0.5255598343335778
# finished 19th training
# training loss: 0.2535739541053772, training iou: 0.5717887874097236
# validation loss: 0.32204383201897147, validation iou: 0.5293802351526964
# finished 20th training
# training loss: 0.25448648631572723, training iou: 0.5735204302624306
# validation loss: 0.33076757959400616, validation iou: 0.5143620808264884
# finished 21th training
# training loss: 0.24540869891643524, training iou: 0.5651627708044537
# validation loss: 0.32464265832677486, validation iou: 0.5336779102706346
# finished 22th training
# training loss: 0.24125809073448182, training iou: 0.5752127410990578
# validation loss: 0.3139444815926254, validation iou: 0.5303077724037443
# finished 23th training
# training loss: 0.23892935514450073, training iou: 0.5792647822730063
# validation loss: 0.32080031869312126, validation iou: 0.5317499337067816
# finished 24th training
# training loss: 0.24451140463352203, training iou: 0.590828315891065
# validation loss: 0.3304081109662851, validation iou: 0.5397971633467912
# finished 25th training
# training loss: 0.23881961405277252, training iou: 0.573711674723282
# validation loss: 0.3344739057434102, validation iou: 0.5279944754252496
# finished 26th training
# training loss: 0.2328793525695801, training iou: 0.5895389768005043
# validation loss: 0.31925717533255615, validation iou: 0.5238532768300451
# finished 27th training
# training loss: 0.24452783465385436, training iou: 0.575422148640641
# validation loss: 0.3337496770235399, validation iou: 0.5287905886475254
# finished 28th training
# training loss: 0.23631074726581575, training iou: 0.5828518772084693
# validation loss: 0.3069924408569932, validation iou: 0.5373296063563083
# finished 29th training
# training loss: 0.23453716933727264, training iou: 0.5850195105803182
# validation loss: 0.3064310822015007, validation iou: 0.5292732685223012
# finished 30th training
# training loss: 0.22694863080978395, training iou: 0.5868784470441415
# validation loss: 0.32159548522904513, validation iou: 0.5241191125179825
# finished 31th training
# training loss: 0.22524962723255157, training iou: 0.5913030008222642
# validation loss: 0.3172334947002431, validation iou: 0.5320323783273039
# finished 32th training
# training loss: 0.23110508620738984, training iou: 0.5793689989992865
# validation loss: 0.3027098904674252, validation iou: 0.5290595320415786
# finished 33th training
# training loss: 0.22876218259334563, training iou: 0.5893330210174879
# validation loss: 0.30365034798160195, validation iou: 0.543327720188022
# finished 34th training
# training loss: 0.2367090940475464, training iou: 0.5729600373494619
# validation loss: 0.32984610289956134, validation iou: 0.5197134455428333
# finished 35th training
# training loss: 0.2245277136564255, training iou: 0.5902685700973398
# validation loss: 0.32739914655685426, validation iou: 0.5127366901570044
# finished 36th training
# training loss: 0.23460503816604614, training iou: 0.58218596827293
# validation loss: 0.313525419558088, validation iou: 0.5097035515445945
# finished 37th training
# training loss: 0.2271709620952606, training iou: 0.5815538324750185
# validation loss: 0.3401109226668874, validation iou: 0.48922288485991916
# finished 38th training
# training loss: 0.22646134197711945, training iou: 0.5873511734893506
# validation loss: 0.30981617191185556, validation iou: 0.5074357157836286
# finished 39th training
# training loss: 0.22264207005500794, training iou: 0.5885003266208294
# validation loss: 0.34210425447672604, validation iou: 0.49792094848177876
# finished 40th training
# training loss: 0.2309163898229599, training iou: 0.5853125742198081
# validation loss: 0.305444640138497, validation iou: 0.5111998431638844
# finished 41th training
# training loss: 0.2311498761177063, training iou: 0.5904870185624802
# validation loss: 0.32589456578716636, validation iou: 0.5102624977970157
# finished 42th training
# training loss: 0.22571247518062593, training iou: 0.5897974752030756
# validation loss: 0.3213644322939217, validation iou: 0.5178748081579082
# finished 43th training
# training loss: 0.22586372196674348, training iou: 0.5849086863787128
# validation loss: 0.3351758553336064, validation iou: 0.5096705661233075
# finished 44th training
# training loss: 0.23006586134433746, training iou: 0.583656778071586
# validation loss: 0.3348912035115063, validation iou: 0.507361939571251
# finished 45th training
# training loss: 0.22757276594638826, training iou: 0.5848238425228742
# validation loss: 0.3227060897275805, validation iou: 0.5112239248212961
# finished 46th training
# training loss: 0.2207034260034561, training iou: 0.6040458070292788
# validation loss: 0.3272576394180457, validation iou: 0.5105117845467675
# finished 47th training
# training loss: 0.22760721445083618, training iou: 0.5945741658176691
# validation loss: 0.31988083897158504, validation iou: 0.5152695056847068
# finished 48th training
# training loss: 0.22833068966865538, training iou: 0.5922842745267729
# validation loss: 0.32038756826271614, validation iou: 0.5120760850991417
# finished 49th training
# training loss: 0.22684854567050933, training iou: 0.5925486545967964
# validation loss: 0.31911567558224, validation iou: 0.5096934488522179
# finished 50th training
# training loss: 0.2290893942117691, training iou: 0.5883544448927468
# validation loss: 0.32866708692163227, validation iou: 0.506999750220319
