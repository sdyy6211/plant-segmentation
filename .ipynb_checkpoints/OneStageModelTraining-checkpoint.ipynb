# %%
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import requests
import os
import numpy as np

import torch
from torchvision import models
from torch.nn import CrossEntropyLoss
from torch.nn.functional import softmax
from torch.optim import Adam,lr_scheduler
from torch.nn import functional as F
from torchvision import transforms
from torch.utils.data import Dataset

# %%
Deeplabv3plus_path = r'E:\codes\python\area51m\pytorch_deeplab_xception'
Data_path = r'E:\UCL\Dissertation\label'
TrainingLabelNames = 'TrainingLabelNames.csv'
TestLabelNames = 'TestLabelNames.csv'
Training_input_folder = 'input'
Training_label_folder = 'label'
Test_input_folder = 'input_test'
Test_label_folder = 'label_test'
ModelPath = r'E:\data\MODELS' 
OneStageModelName = 'model_deeplabv3+_xception'

# %%
from utils import *
import sys
import os

device = torch.device("cuda:0")

sys.path.append(Deeplabv3plus_path)
from pytorch_deeplab_xception.modeling import deeplab

os.environ['TORCH_HOME'] = ModelPath

# %%
num_c = 8

dl = deeplab.DeepLab(num_classes=num_c,backbone = 'xception',output_stride = 16).to(device)

for name, param in dl.named_parameters():                
    if name.startswith('backbone'):
        param.requires_grad = False

# %%
image_size = (900,900)

transform = transforms.Compose([transforms.Resize(image_size),
                                transforms.ColorJitter(brightness = 0.15,
                                                       saturation = 0.1,
                                                       hue = 0.01,
                                                       contrast = 0.15),
                                transforms.ToTensor(),
                                transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# %%
data = pd.read_csv(r'{0}\{1}'.format(Data_path,TrainingLabelNames))

dataset_train = Segdata(transform,image_size,
                        TrainingLabelNames,Data_path,[Training_input_folder,Training_label_folder])

dataset_test = Segdata(transform,image_size,
                       TestLabelNames,Data_path,[Test_input_folder,Test_label_folder])

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=6, 
                                         shuffle=True, num_workers=0,drop_last  = True)

dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=1, num_workers=0,drop_last  = False)

# %%
freq = 1/get_frequency(data,image_size,num_c,Data_path,Training_label_folder)

# %%
plist = [
         {'params': dl.parameters(),'lr':1e-2}
         ]

criterion = CrossEntropyLoss(ignore_index = 0,weight = torch.log(freq)/torch.log(freq).sum())

optimizer = Adam(params=plist)
        
scheduler = lr_scheduler.StepLR(optimizer, step_size=50,gamma=0.1)

loss_list_train = []

loss_list_test = []

best_val_loss = float('inf')

n_epoch = 100

# %%
for epoch in range(n_epoch):
    training_loss,training_iou = train(dl,dataloader_train,optimizer,criterion,loss_list_train,num_c)
    val_loss,val_iou = evaluate(dl,dataloader_test,criterion,loss_list_test,num_c)
    scheduler.step()
    print('finished {0}th training'.format(epoch+1))
    print('training loss: {0}, training iou: {1}'.format(training_loss.item(),training_iou))
    print('validation loss: {0}, validation iou: {1}'.format(val_loss.item(),val_iou))
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(dl.state_dict(), r'{0}\{1}_best_onestage.pt'.format(ModelPath,OneStageModelName))
torch.save(dl.state_dict(), r'{0}\{1}_last_onestage.pt'.format(ModelPath,OneStageModelName))
# Out:
# finished 1th training
# training loss: 1.4605091373125711, training iou: 0.1903391508378154
# validation loss: 6.12741032242775, validation iou: 0.24161099822266602
# finished 2th training
# training loss: 0.7544103542963664, training iou: 0.2666204485456272
# validation loss: 10.695378389954566, validation iou: 0.26329965836573027
# finished 3th training
# training loss: 0.6808920423189799, training iou: 0.30726286429148303
# validation loss: 9.767206099629401, validation iou: 0.2879768629043402
# finished 4th training
# training loss: 0.624762103954951, training iou: 0.31297707257836055
# validation loss: 9.23909844905138, validation iou: 0.30917177980967786
# finished 5th training
# training loss: 0.5727751990159352, training iou: 0.32783065910371517
# validation loss: 6.479605078697205, validation iou: 0.2900688430626431
# finished 6th training
# training loss: 0.4911661525567373, training iou: 0.3364535562197079
# validation loss: 1.3301705319434405, validation iou: 0.34332573924919335
# finished 7th training
# training loss: 0.46558472911516824, training iou: 0.3517562013862971
# validation loss: 0.5396859124302864, validation iou: 0.39658052873024185
# finished 8th training
# training loss: 0.46968711018562315, training iou: 0.36323115812516954
# validation loss: 0.5963778410106897, validation iou: 0.385703836083389
# finished 9th training
# training loss: 0.4743557095527649, training iou: 0.330347125887582
# validation loss: 0.7452670313417912, validation iou: 0.28080222378122405
# finished 10th training
# training loss: 0.43393355011940005, training iou: 0.3618252979002532
# validation loss: 0.6268326498568058, validation iou: 0.3904549425710504
# finished 11th training
# training loss: 0.40268299778302513, training iou: 0.3742882158175932
# validation loss: 0.5067841470241546, validation iou: 0.36377202408487364
# finished 12th training
# training loss: 0.40256105264027914, training iou: 0.37877861192871237
# validation loss: 0.43917634077370166, validation iou: 0.39247809410721574
# finished 13th training
# training loss: 0.37938705484072366, training iou: 0.3744967442867492
# validation loss: 0.6226765777915716, validation iou: 0.3670624842443604
# finished 14th training
# training loss: 0.4249062716960907, training iou: 0.37482651899577335
# validation loss: 0.4872788429260254, validation iou: 0.360516627674498
# finished 15th training
# training loss: 0.39311635891596475, training iou: 0.36897617358354134
# validation loss: 0.4612697198987007, validation iou: 0.3805235713952628
# finished 16th training
# training loss: 0.4061831434567769, training iou: 0.37334147790248273
# validation loss: 0.4708503060042858, validation iou: 0.38495326761950743
# finished 17th training
# training loss: 0.3633346031109492, training iou: 0.3881847451629855
# validation loss: 0.5042135722935199, validation iou: 0.39748907274163203
# finished 18th training
# training loss: 0.3650792876879374, training iou: 0.39828861718595676
# validation loss: 0.518913035094738, validation iou: 0.37823406091933837
# finished 19th training
# training loss: 0.3565715909004211, training iou: 0.3994967272572417
# validation loss: 0.5261472504585981, validation iou: 0.39490858233284737
# finished 20th training
# training loss: 0.3455657442410787, training iou: 0.3974692955542735
# validation loss: 0.45030827075242996, validation iou: 0.36759256490411235
# finished 21th training
# training loss: 0.34104123115539553, training iou: 0.3999267732871891
# validation loss: 0.481267698854208, validation iou: 0.38762833794563745
# finished 22th training
# training loss: 0.34109303454558054, training iou: 0.401848596574078
# validation loss: 0.44721015691757204, validation iou: 0.4238957885652949
# finished 23th training
# training loss: 0.310251717766126, training iou: 0.41451870230664817
# validation loss: 0.5690997492522001, validation iou: 0.4294349711638613
# finished 24th training
# training loss: 0.3452607154846191, training iou: 0.40188872632544914
# validation loss: 0.3863492239266634, validation iou: 0.41121409948341536
# finished 25th training
# training loss: 0.3089576780796051, training iou: 0.39942909470650334
# validation loss: 0.5481849329546093, validation iou: 0.4354603014567767
# finished 26th training
# training loss: 0.31719906330108644, training iou: 0.4116359341386842
# validation loss: 0.4043378885835409, validation iou: 0.4512700896078242
# finished 27th training
# training loss: 0.2868341714143753, training iou: 0.4202306865655266
# validation loss: 0.5112686872482299, validation iou: 0.4127783877027884
# finished 28th training
# training loss: 0.3157269597053528, training iou: 0.4181425088986435
# validation loss: 0.44348949007689953, validation iou: 0.4082667207927434
# finished 29th training
# training loss: 0.30970973074436187, training iou: 0.4172735799908847
# validation loss: 0.4748592749238014, validation iou: 0.4254754550788878
# finished 30th training
# training loss: 0.3102008412281672, training iou: 0.4005314909155531
# validation loss: 0.5396901227533817, validation iou: 0.43552853334165986
# finished 31th training
# training loss: 0.319571057955424, training iou: 0.40625163973769446
# validation loss: 0.45879943370819093, validation iou: 0.39440548242742324
# finished 32th training
# training loss: 0.2895695805549622, training iou: 0.41935946822826353
# validation loss: 0.401214100420475, validation iou: 0.4482397743878942
# finished 33th training
# training loss: 0.2756442427635193, training iou: 0.4285543891429186
# validation loss: 0.4473684515804052, validation iou: 0.45418928981962947
# finished 34th training
# training loss: 0.2867202172676722, training iou: 0.4188668794244014
# validation loss: 0.463711005076766, validation iou: 0.42428620176019843
# finished 35th training
# training loss: 0.2677870184183121, training iou: 0.4405769151869311
# validation loss: 0.43560797460377215, validation iou: 0.4360391658279914
# finished 36th training
# training loss: 0.272998309135437, training iou: 0.442506627203887
# validation loss: 0.5491879519075156, validation iou: 0.43614237683016954
# finished 37th training
# training loss: 0.27233365674813587, training iou: 0.4339448095912734
# validation loss: 0.40631501115858554, validation iou: 0.4332760957431446
# finished 38th training
# training loss: 0.2783003161350886, training iou: 0.4393389444821969
# validation loss: 0.5123849496245384, validation iou: 0.43252985294518176
# finished 39th training
# training loss: 0.27306540111700695, training iou: 0.4350877740829943
# validation loss: 0.552523585408926, validation iou: 0.3574744618623977
# finished 40th training
# training loss: 0.2913656195004781, training iou: 0.42183706685108274
# validation loss: 0.4388890638947487, validation iou: 0.39720616969217215
# finished 41th training
# training loss: 0.28125009934107464, training iou: 0.4259710341423489
# validation loss: 0.38183520510792734, validation iou: 0.43638856628120665
# finished 42th training
# training loss: 0.27204861243565875, training iou: 0.4317014285066162
# validation loss: 0.432226662710309, validation iou: 0.42183350008973114
# finished 43th training
# training loss: 0.2844613273938497, training iou: 0.4364891566381947
# validation loss: 0.5815331347286701, validation iou: 0.36501703975441
# finished 44th training
# training loss: 0.2810871889193853, training iou: 0.4575644293502943
# validation loss: 0.4718866743147373, validation iou: 0.43754319195975394
# finished 45th training
# training loss: 0.28986306488513947, training iou: 0.43686129618665626
# validation loss: 0.490751364454627, validation iou: 0.46252808942740564
# finished 46th training
# training loss: 0.26242766082286834, training iou: 0.431265615808699
# validation loss: 0.47834121324121953, validation iou: 0.46159564641099815
# finished 47th training
# training loss: 0.25734447737534843, training iou: 0.4456990208114882
# validation loss: 0.4896799258887768, validation iou: 0.44256579345155805
# finished 48th training
# training loss: 0.24788125952084858, training iou: 0.45571077471075255
# validation loss: 0.5710210923105479, validation iou: 0.40425968631962084
# finished 49th training
# training loss: 0.2376725882291794, training iou: 0.4447983739750782
# validation loss: 0.5602169413119554, validation iou: 0.4549379749458492
# finished 50th training
# training loss: 0.2730619649092356, training iou: 0.4420292161959678
# validation loss: 0.43307989165186883, validation iou: 0.4747033350584421
# finished 51th training
# training loss: 0.24257769683996835, training iou: 0.4560788282828374
# validation loss: 0.39273151755332947, validation iou: 0.44717738895128
# finished 52th training
# training loss: 0.22331025103727978, training iou: 0.4538922411295817
# validation loss: 0.394605265930295, validation iou: 0.4497285107459249
# finished 53th training
# training loss: 0.20899334748586018, training iou: 0.46370912254310653
# validation loss: 0.4312158450484276, validation iou: 0.4610177936008064
# finished 54th training
# training loss: 0.20493190685908, training iou: 0.4598163772653135
# validation loss: 0.44283865578472614, validation iou: 0.47207518542513915
# finished 55th training
# training loss: 0.20565731426080067, training iou: 0.46663401965989415
# validation loss: 0.4221669856458902, validation iou: 0.46356226316955534
# finished 56th training
# training loss: 0.21933413644631702, training iou: 0.4563335352917453
# validation loss: 0.4105585809797049, validation iou: 0.4619236846429994
# finished 57th training
# training loss: 0.21530180275440217, training iou: 0.4573934978001584
# validation loss: 0.4200366403907537, validation iou: 0.4798730029300944
# finished 58th training
# training loss: 0.2106654425462087, training iou: 0.4629186479996182
# validation loss: 0.38354521691799165, validation iou: 0.4558163144155663
# finished 59th training
# training loss: 0.20419731537501018, training iou: 0.4727809096549934
# validation loss: 0.43397987335920335, validation iou: 0.4707454167824457
# finished 60th training
# training loss: 0.2037424623966217, training iou: 0.4727259832934392
# validation loss: 0.4522743407636881, validation iou: 0.46666356957782196
# finished 61th training
# training loss: 0.20114529629548392, training iou: 0.4658529910497076
# validation loss: 0.35021103657782077, validation iou: 0.4674226654075536
# finished 62th training
# training loss: 0.20706843932469685, training iou: 0.46157274799265274
# validation loss: 0.37963023893535136, validation iou: 0.4657883725486188
# finished 63th training
# training loss: 0.199028480052948, training iou: 0.4764387558170053
# validation loss: 0.4432988665997982, validation iou: 0.4708874941107335
# finished 64th training
# training loss: 0.20254357407490411, training iou: 0.46818939699846684
# validation loss: 0.44409114103764297, validation iou: 0.4635577133387877
# finished 65th training
# training loss: 0.19073435763518015, training iou: 0.47530020154205377
# validation loss: 0.4386749256402254, validation iou: 0.47600930560938914
# finished 66th training
# training loss: 0.2099739506840706, training iou: 0.4590354136352653
# validation loss: 0.39727094657719136, validation iou: 0.47442424431046215
# finished 67th training
# training loss: 0.1911529555916786, training iou: 0.46662918423465466
# validation loss: 0.3932529717683792, validation iou: 0.4673808743192554
# finished 68th training
# training loss: 0.20354871799548466, training iou: 0.4668576352195248
# validation loss: 0.5036292800679802, validation iou: 0.4555103458831781
# finished 69th training
# training loss: 0.18512765268484752, training iou: 0.4732435497961786
# validation loss: 0.42303307093679904, validation iou: 0.4570455851202597
# finished 70th training
# training loss: 0.1821741799513499, training iou: 0.47734114193713917
# validation loss: 0.41813232786953447, validation iou: 0.46923591844708384
# finished 71th training
# training loss: 0.19427811602751413, training iou: 0.46360476755649954
# validation loss: 0.35713736712932587, validation iou: 0.4750618338852216
# finished 72th training
# training loss: 0.2027237484852473, training iou: 0.47175279741376486
# validation loss: 0.3907793093472719, validation iou: 0.4775191014757835
# finished 73th training
# training loss: 0.19892945090929667, training iou: 0.4667793950693477
# validation loss: 0.37909857369959354, validation iou: 0.47698622708731825
# finished 74th training
# training loss: 0.19406875024239223, training iou: 0.4801470173903402
# validation loss: 0.40583637431263925, validation iou: 0.47183198145720145
# finished 75th training
# training loss: 0.1915285478035609, training iou: 0.46356051601454035
# validation loss: 0.3849403202533722, validation iou: 0.46470560876879424
# finished 76th training
# training loss: 0.19823609689871471, training iou: 0.4674098605498704
# validation loss: 0.3949282646179199, validation iou: 0.46868104755202245
# finished 77th training
# training loss: 0.1849888026714325, training iou: 0.4688001907262999
# validation loss: 0.38501167446374895, validation iou: 0.479009155145373
# finished 78th training
# training loss: 0.17697135011355083, training iou: 0.4750105390179879
# validation loss: 0.3674820352345705, validation iou: 0.46715846694557844
# finished 79th training
# training loss: 0.19141546388467154, training iou: 0.47294378544486304
# validation loss: 0.43403178043663504, validation iou: 0.46542268762340216
# finished 80th training
# training loss: 0.2017728179693222, training iou: 0.4742042495848317
# validation loss: 0.41255138255655766, validation iou: 0.4648170316284693
# finished 81th training
# training loss: 0.2019790475567182, training iou: 0.4658886231184789
# validation loss: 0.4123006138950586, validation iou: 0.4664080484813268
# finished 82th training
# training loss: 0.20615847110748292, training iou: 0.4607858326986902
# validation loss: 0.4111704111099243, validation iou: 0.465473229130916
# finished 83th training
# training loss: 0.19888421992460886, training iou: 0.4709600275696862
# validation loss: 0.3903856981545687, validation iou: 0.4713976245148447
# finished 84th training
# training loss: 0.18603374063968658, training iou: 0.4708024149872394
# validation loss: 0.43234262242913246, validation iou: 0.46425234262858683
# finished 85th training
# training loss: 0.19176252732674282, training iou: 0.46759366268782426
# validation loss: 0.39205933921039104, validation iou: 0.47464001973982306
# finished 86th training
# training loss: 0.18090716103712717, training iou: 0.47351890719816836
# validation loss: 0.3771347928792238, validation iou: 0.47819167612518276
# finished 87th training
# training loss: 0.18544109563032787, training iou: 0.4738873525544543
# validation loss: 0.399729673191905, validation iou: 0.47461977812373773
# finished 88th training
# training loss: 0.18021080990632374, training iou: 0.46118819671635286
# validation loss: 0.36542499978095294, validation iou: 0.4707048271404397
# finished 89th training
# training loss: 0.19250478198130924, training iou: 0.4734668628966882
# validation loss: 0.4135602002963424, validation iou: 0.48657208035176935
# finished 90th training
# training loss: 0.1713295857111613, training iou: 0.48000251108273323
# validation loss: 0.371596560254693, validation iou: 0.4949213085751317
# finished 91th training
# training loss: 0.19442529330650965, training iou: 0.46710583011378
# validation loss: 0.4231329392641783, validation iou: 0.4815836011875727
# finished 92th training
# training loss: 0.18649967809518178, training iou: 0.4747220606299954
# validation loss: 0.3895840909332037, validation iou: 0.4878287977232619
# finished 93th training
# training loss: 0.18078415095806122, training iou: 0.4841269441083981
# validation loss: 0.3976516179740429, validation iou: 0.47519451796930345
# finished 94th training
# training loss: 0.18861883282661437, training iou: 0.47156913300330455
# validation loss: 0.44117134883999826, validation iou: 0.4592251000771276
# finished 95th training
# training loss: 0.16133194863796235, training iou: 0.4784661412520844
# validation loss: 0.48956664800643923, validation iou: 0.46555021676715186
# finished 96th training
# training loss: 0.16322633177042006, training iou: 0.4848186940747283
# validation loss: 0.4759618975222111, validation iou: 0.4697118956485197
# finished 97th training
# training loss: 0.19483518799146016, training iou: 0.47361281657061943
# validation loss: 0.39293335676193236, validation iou: 0.46243544693883554
# finished 98th training
# training loss: 0.17597376505533854, training iou: 0.47769799192428003
# validation loss: 0.3721557155251503, validation iou: 0.46000745555809675
# finished 99th training
# training loss: 0.17782478928565978, training iou: 0.4715654006858182
# validation loss: 0.40413791574537755, validation iou: 0.4800480898310977
# finished 100th training
# training loss: 0.17287257661422092, training iou: 0.47194234686192715
# validation loss: 0.3949176609516144, validation iou: 0.48475144163709905
